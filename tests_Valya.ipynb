# %%
import numpy as np
# from joblib import Parallel, delayed
from os.path import exists
import matplotlib.pyplot as plt

from assignment.util import *
from assignment.TSP import *
from assignment.cooling import *
from assignment.SAMinimizer import *

# %%
cost_eil51, cost_a280, cost_pcb442 = map(first, COST_FUNCTION_PAIRS)
delta_cost_eil51, delta_cost_a280, delta_cost_pcb442 = map(second, COST_FUNCTION_PAIRS)

OPT_TOUR_FILES
# Out:
# ['eil51.opt.tour.txt', 'a280.opt.tour.txt', 'pcb442.opt.tour.txt']

# %%
_, eil51_tour = read_tour(OPT_TOUR_FILES[0])
print(eil51_tour)

if eil51_tour[-1] < 0:
    eil51_tour[-1] = 0

eil51_tsp = import_tsp_file("eil51.tsp.txt")

eil51_tsp = np.around(eil51_tsp)

eil51_tsp = eil51_tsp.astype(int)

print(eil51_tsp)
            
print(eil51_tour)

# benchmark = eil51_tsp[eil51_tour]
# Out:
# [ 0 21  7 25 30 27  2 35 34 19  1 28 20 15 49 33 29  8 48  9 38 32 44 14
#  43 41 39 18 40 12 24 13 23 42  6 22 47  5 26 50 45 11 46 17  3 16 36  4
#  37 10 31 -2]
# [[ 1 37 52]
#  [ 2 49 49]
#  [ 3 52 64]
#  [ 4 20 26]
#  [ 5 40 30]
#  [ 6 21 47]
#  [ 7 17 63]
#  [ 8 31 62]
#  [ 9 52 33]
#  [10 51 21]
#  [11 42 41]
#  [12 31 32]
#  [13  5 25]
#  [14 12 42]
#  [15 36 16]
#  [16 52 41]
#  [17 27 23]
#  [18 17 33]
#  [19 13 13]
#  [20 57 58]
#  [21 62 42]
#  [22 42 57]
#  [23 16 57]
#  [24  8 52]
#  [25  7 38]
#  [26 27 68]
#  [27 30 48]
#  [28 43 67]
#  [29 58 48]
#  [30 58 27]
#  [31 37 69]
#  [32 38 46]
#  [33 46 10]
#  [34 61 33]
#  [35 62 63]
#  [36 63 69]
#  [37 32 22]
#  [38 45 35]
#  [39 59 15]
#  [40  5  6]
#  [41 10 17]
#  [42 21 10]
#  [43  5 64]
#  [44 30 15]
#  [45 39 10]
#  [46 32 39]
#  [47 25 32]
#  [48 25 55]
#  [49 48 28]
#  [50 56 37]
#  [51 30 40]]
# [ 0 21  7 25 30 27  2 35 34 19  1 28 20 15 49 33 29  8 48  9 38 32 44 14
# ...

# %%
benchmark_order = np.concatenate((np.array([eil51_tsp[eil51_tour[i]] for i in range(len(eil51_tour))]),np.array([eil51_tsp[0]])))

fig = plt.figure(figsize = (6,6))
plt.scatter(eil51_tsp[:,1],eil51_tsp[:,2], color = "darkred")
plt.plot(benchmark_order[:,1],benchmark_order[:,2], color = "darkgreen")
plt.xlabel("x")
plt.ylabel("y")

plt.show()

# %%
_, a280_tour = read_tour(OPT_TOUR_FILES[1])

a280_tour = np.append(a280_tour, a280_tour[0]) #adding first value to the end to close the loop

print(a280_tour)

a280_tsp = import_tsp_file("a280.tsp.txt")

a280_tsp = np.around(a280_tsp)

a280_tsp = a280_tsp.astype(int)

benchmark_order_280 = np.concatenate((np.array([a280_tsp[a280_tour[i]] for i in range(len(a280_tour))]),np.array([a280_tsp[0]])))

fig = plt.figure(figsize = (10,10))
plt.scatter(a280_tsp[:,1],a280_tsp[:,2], color = "darkred")
plt.plot(benchmark_order_280[:,1],benchmark_order_280[:,2], color = "darkgreen")
plt.xlabel("x")
plt.ylabel("y")

plt.show()
# Out:
# [  0   1 241 242 243 240 239 238 237 236 235 234 233 232 231 230 245 244
#  246 249 250 229 228 227 226 225 224 223 222 221 220 219 218 217 216 215
#  214 213 212 211 210 209 206 205 204 203 202 201 200 197 196 195 194 193
#  192 191 190 189 188 187 186 185 184 183 182 181 180 175 179 178 149 177
#  176 150 151 155 152 154 153 128 129 130  19  20 127 126 125 124 123 122
#  121 120 119 118 156 157 158 159 174 160 161 162 163 164 165 166 167 168
#  169 171 170 172 173 106 105 104 103 102 101 100  99  98  97  96  95  94
#   93  92  91  90  89  88 108 107 109 110 111  87  86 112 113 114 116 115
#   85  84  83  82  81  80  79  78  77  76  75  74  73  72  71  70  69  68
#   67  66  65  64  63  57  56  55  54  53  52  51  50  49  48  47  46  45
#   44  43  58  62  61 117  60  59  42  41  40  39  38  37  36  35  34  33
#   32  31  30  29  28  27  26  25  21  24  22  23  13  14  12  11  10   9
#    8   7   6   5   4   3 276 275 274 273 272 271 270  15  16  17  18 131
# ...
